# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
c = [1]
alpha=0.8
for t in range(0,100):
    c.append(c[-1]*(1-alpha))
plt.plot(c)
plt.axhline(y=np.exp(-1))
plt.scatter(1/alpha,np.exp(-1))
plt.xlim([1/alpha -10,1/alpha + 10])
plt.ylim([0.3,0.4])
# Out:
# (0.3, 0.4)
