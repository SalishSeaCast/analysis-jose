# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from random import sample
from math import ceil,sin,cos, atan2, pi, sqrt
import pandas as pd
from cartopy import crs, feature

# %%
Point_At = pd.read_csv('/Users/jvalenti/Downloads/7795-01-JAN-2018_slev.csv',index_col=[0])

# %%
SLEV = np.array(Point_At['SLEV(metres)'])
Days = [np.datetime64(day) for day in Point_At.index]
plt.plot(Days[0::3],SLEV[0::3])
plt.grid()
