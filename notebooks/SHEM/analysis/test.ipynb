# %%
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = xr.open_dataset('/home/jvalenti/MEOPAR/tracers/north/OBC_Plankton_fromClimate_2007_2019_v201905.nc',decode_times=False)
df2 = xr.open_dataset('/home/jvalenti/MEOPAR/tracers/west/bioOBC_West_HBAC_const202410.nc',decode_times=False)

# %%
df2
# Out:
# <xarray.Dataset> Size: 2MB
# Dimensions:       (time_counter: 1, deptht: 40, yb: 10, xbT: 95)
# Coordinates:
#   * time_counter  (time_counter) float32 4B 0.0
#   * deptht        (deptht) float32 160B 0.5 1.5 2.5 3.5 ... 387.6 414.5 441.5
# Dimensions without coordinates: yb, xbT
# Data variables:
#     NH4           (time_counter, deptht, yb, xbT) float32 152kB ...
#     DIA           (time_counter, deptht, yb, xbT) float32 152kB ...
#     CRY           (time_counter, deptht, yb, xbT) float32 152kB ...
#     MYRI          (time_counter, deptht, yb, xbT) float32 152kB ...
#     MICZ          (time_counter, deptht, yb, xbT) float32 152kB ...
#     PON           (time_counter, deptht, yb, xbT) float32 152kB ...
#     DON           (time_counter, deptht, yb, xbT) float32 152kB ...
#     bSi           (time_counter, deptht, yb, xbT) float32 152kB ...
#     O2            (time_counter, deptht, yb, xbT) float32 152kB ...
#     tur           (time_counter, deptht, yb, xbT) float32 152kB ...
#     HBAC          (time_counter, deptht, yb, xbT) float32 152kB ...

# %%
df
# Out:
# <xarray.Dataset> Size: 26MB
# Dimensions:                       (time_counter: 12, deptht: 40, yb: 1, xbT: 950)
# Coordinates:
#   * time_counter                  (time_counter) float64 96B 1.358e+18 ... 1....
#   * deptht                        (deptht) float32 160B 0.5 1.5 ... 414.5 441.5
#   * yb                            (yb) int64 8B 1
#   * xbT                           (xbT) int64 8kB 0 1 2 3 4 ... 946 947 948 949
# Data variables:
#     diatoms                       (time_counter, deptht, yb, xbT) float64 4MB ...
#     flagellates                   (time_counter, deptht, yb, xbT) float64 4MB ...
#     microzooplankton              (time_counter, deptht, yb, xbT) float64 4MB ...
#     ammonium                      (time_counter, deptht, yb, xbT) float64 4MB ...
#     dissolved_organic_nitrogen    (time_counter, deptht, yb, xbT) float64 4MB ...
#     particulate_organic_nitrogen  (time_counter, deptht, yb, xbT) float64 4MB ...
#     biogenic_silicon              (time_counter, deptht, yb, xbT) float64 4MB ...
# Attributes:
#     creator_email:         sallen@eoas.ubc.ca
#     creator_name:          Salish Sea MEOPAR Project Contributors
#     creator_url:           https://salishsea-meopar-docs.readthedocs.org/
#     institution:           UBC EOAS
#     institution_fullname:  Earth, Ocean & Atmospheric Sciences, University of...
#     summary:               ['Diatoms, flagellates, microzooplankton, ammonimu...
#     source:                https://github.com/SalishSeaCast/tools/blob/master...
#     history:               [2022-05-12] File creation.

# %%
df.diatoms.shape
# Out:
# (12, 40, 1, 950)

# %%
df['HBAC'] = df.diatoms*0.42/2.4

# %%
df.to_netcdf('/home/jvalenti/MEOPAR/tracers/west/HBAC_fromdiatClimate_2007_2019_v201905.nc')
