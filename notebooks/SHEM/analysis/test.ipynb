# %%
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = xr.open_dataset('/home/jvalenti/MEOPAR/tracers/north/OBC_Plankton_fromClimate_2007_2019_v201905.nc',decode_times=False)
df2 = xr.open_dataset('/home/jvalenti/MEOPAR/tracers/west/OBC_Plankton_fromClimate_2007_2019_v201905.nc',decode_times=False)

# %%
df.diatoms.shape
# Out:
# (12, 40, 1, 950)

# %%
df['HBAC'] = df.diatoms*0.42/2.4

# %%
df.to_netcdf('/home/jvalenti/MEOPAR/tracers/west/HBAC_fromdiatClimate_2007_2019_v201905.nc')
