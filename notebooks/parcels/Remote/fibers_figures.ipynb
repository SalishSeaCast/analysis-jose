# %%
# %matplotlib inline

import sys
import os
import numpy as np
import xarray as xr
from mpl_toolkits import mplot3d
from matplotlib import pyplot as plt, animation, rc
from datetime import datetime, timedelta
from dateutil.parser import parse
from cartopy import crs, feature

from IPython.display import Image
rc('animation', html='html5')

sys.path.append('/home/jvalenti/MOAD/analysis-jose/notebooks/parcels')
from OP_functions_fibers import *

# %%
# Define paths
local = 0 #Set to 0 when working on server
paths = path(local)

# %% [markdown]
# ## THIS MUST BE THE SAME USED WHEN RUNNING PARCELS

# %%
start = datetime(2018, 12, 23) #Start date
# Set Time length [days] and timestep [seconds]
length = 60
duration = timedelta(days=length)
dt = 90 #toggle between - or + to pick backwards or forwards
N = 6 # number of deploying locations
n = 50 # 1000   # number of particles per location
dmin = [0,0,0,0,0,70] #minimum depth
dd = 20 #max depth difference from dmin
x_offset, y_offset, zvals = p_deploy(N,n,dmin,dd)

# %%
# Set output file name.  Maybe change for each run
fn = 'Fibers_winter' + '_'.join(d.strftime('%Y%m%d')+'_1n' for d in [start, start+duration]) + '.nc'
outfile = os.path.join(paths['out'], fn)

# %%
Dat=xr.open_dataset(paths['coords'],decode_times=False)
outf_lat=Dat['nav_lat'][445,304]
outf_lon=Dat['nav_lon'][445,304]

# %%
lon = np.zeros([N,n])
lat = np.zeros([N,n])
# Execute run
clon, clat = [-123.901172,-125.155849,-123.207648,-122.427508,-123.399769,float(outf_lon)], [49.186308,49.975326,49.305448,47.622403,48.399420,float(outf_lat)]  # choose horizontal centre of the particle cloud
for i in range(N):
    lon[i,:]=(clon[i] + x_offset[i,:])
    lat[i,:]=(clat[i] + y_offset[i,:])
z = zvals

# %%
coords = xr.open_dataset(paths['coords'], decode_times=False)
mask = xr.open_dataset(paths['mask'])
ds = xr.open_dataset(outfile)

# %%
visual(outfile,N,n,clon,clat,dmin,dd,0,-1,local)

# %%
profile(N,n,length,outfile,local)

# %%
#anim=mapanimation(outfile,N,n,clon,clat,15,0)
#anim

# %%
sn=[]
fig = plt.figure(figsize=(19, 8))

#ax = plt.axes(xlim=(-127,-121),ylim=(46.8,51.2))
sed= {0: "w", 1: "k"}

#sn.append(ax.scatter(ds.lon[:,600], ds.lat[:,600],c=sed[ds.sediment[:,100]],s=1))
# Out:
# 'k'

# %%
fps=60
anim = mapanimation(outfile,N,n,clon,clat,fps,local)
f = r"/home/jvalenti/MOAD/animations/sinksblack.gif" 
FFwriter = animation.FFMpegWriter()
anim.save(f, writer = FFwriter)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6954/4128375218.py in <module>
#       3 f = r"/home/jvalenti/MOAD/animations/sinksblack.gif"
#       4 FFwriter = animation.FFMpegWriter()
# ----> 5 anim.save(f, writer = FFwriter)
#
# ~/conda_envs/parcels/lib/python3.9/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1158                                _is_saving=True, manager=None):
#    1159             for anim in all_anim:
# -> 1160                 anim._init_draw()  # Clear the initial frame
#    1161             frame_number = 0
#    1162             # TODO: Currently only FuncAnimation has a save_count
#
# ~/conda_envs/parcels/lib/python3.9/site-packages/matplotlib/animation.py in _init_draw(self)
#    1751         # artists.
#    1752         if self._init_func is None:
# -> 1753             self._draw_frame(next(self.new_frame_seq()))
#    1754
#    1755         else:
#
# ~/conda_envs/parcels/lib/python3.9/site-packages/matplotlib/animation.py in _draw_frame(self, framedata)
#    1774         # Call the func with framedata and args. If blitting is desired,
#    1775         # func needs to return a sequence of any artists that were modified.
# -> 1776         self._drawn_artists = self._func(framedata, *self._args)
#    1777
#    1778         if self._blit:
#
# ~/MOAD/analysis-jose/notebooks/parcels/OP_functions_fibers.py in update(frame)
#     111         for scat in ss:
#     112             scat.remove()
# --> 113         for scat2 in sn:
#     114             scat2.remove()
#     115
#
# NameError: name 'sn' is not defined
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7fadbabc2dc0> (for post_execute):
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/conda_envs/parcels/lib/python3.9/site-packages/matplotlib/pyplot.py in post_execute()
#     137             def post_execute():
#     138                 if matplotlib.is_interactive():
# --> 139                     draw_all()
#     140
#     141             # IPython >= 2
#
# ~/conda_envs/parcels/lib/python3.9/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     135         for manager in cls.get_all_fig_managers():
#     136             if force or manager.canvas.figure.stale:
# --> 137                 manager.canvas.draw_idle()
#     138
#     139
#
# ~/conda_envs/parcels/lib/python3.9/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2053         if not self._is_idle_drawing:
#    2054             with self._idle_draw_cntx():
# -> 2055                 self.draw(*args, **kwargs)
#    2056
#    2057     def get_width_height(self):
#
# ~/conda_envs/parcels/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     404              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     405               else nullcontext()):
# --> 406             self.figure.draw(self.renderer)
#     407             # A GUI class may be need to update a window using this draw, so
#     408             # don't forget to call the superclass.
#
# ~/conda_envs/parcels/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# ~/conda_envs/parcels/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/conda_envs/parcels/lib/python3.9/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2798             self.stale = False
#    2799
# -> 2800         self.canvas.draw_event(renderer)
#    2801
#    2802     def draw_artist(self, a):
#
# ~/conda_envs/parcels/lib/python3.9/site-packages/matplotlib/backend_bases.py in draw_event(self, renderer)
#    1790         s = 'draw_event'
#    1791         event = DrawEvent(s, self, renderer)
# -> 1792         self.callbacks.process(s, event)
#    1793
#    1794     def resize_event(self):
#
# ~/conda_envs/parcels/lib/python3.9/site-packages/matplotlib/cbook/__init__.py in process(self, s, *args, **kwargs)
#     273                 except Exception as exc:
#     274                     if self.exception_handler is not None:
# --> 275                         self.exception_handler(exc)
#     276                     else:
#     277                         raise
#
# ~/conda_envs/parcels/lib/python3.9/site-packages/matplotlib/cbook/__init__.py in _exception_printer(exc)
#      87 def _exception_printer(exc):
#      88     if _get_running_interactive_framework() in ["headless", None]:
# ---> 89         raise exc
#      90     else:
#      91         traceback.print_exc()
#
# ~/conda_envs/parcels/lib/python3.9/site-packages/matplotlib/cbook/__init__.py in process(self, s, *args, **kwargs)
#     268             if func is not None:
#     269                 try:
# --> 270                     func(*args, **kwargs)
#     271                 # this does not capture KeyboardInterrupt, SystemExit,
#     272                 # and GeneratorExit
#
# ~/conda_envs/parcels/lib/python3.9/site-packages/matplotlib/animation.py in _start(self, *args)
#     989
#     990         # Now do any initial draw
# --> 991         self._init_draw()
#     992
#     993         # Add our callback for stepping the animation and
#
# ~/conda_envs/parcels/lib/python3.9/site-packages/matplotlib/animation.py in _init_draw(self)
#    1751         # artists.
#    1752         if self._init_func is None:
# -> 1753             self._draw_frame(next(self.new_frame_seq()))
#    1754
#    1755         else:
#
# ~/conda_envs/parcels/lib/python3.9/site-packages/matplotlib/animation.py in _draw_frame(self, framedata)
#    1774         # Call the func with framedata and args. If blitting is desired,
#    1775         # func needs to return a sequence of any artists that were modified.
# -> 1776         self._drawn_artists = self._func(framedata, *self._args)
#    1777
#    1778         if self._blit:
#
# ~/MOAD/analysis-jose/notebooks/parcels/OP_functions_fibers.py in update(frame)
#     111         for scat in ss:
#     112             scat.remove()
# --> 113         for scat2 in sn:
#     114             scat2.remove()
#     115
#
# NameError: name 'sn' is not defined

# %%
with open(f,'rb') as anim:
    display(Image(anim.read()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6291/3334358585.py in <module>
# ----> 1 with open(f,'rb') as anim:
#       2     display(Image(anim.read()))
#
# NameError: name 'f' is not defined
