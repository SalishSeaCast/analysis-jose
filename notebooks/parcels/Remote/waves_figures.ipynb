# %%
# %matplotlib inline

import sys
import os
import numpy as np
import xarray as xr
from matplotlib import pyplot as plt, animation, rc
from datetime import datetime, timedelta
from dateutil.parser import parse
from cartopy import crs, feature

from IPython.display import Image
rc('animation', html='html5')

sys.path.append('/home/jvalenti/MOAD/analysis-jose/notebooks/parcels')
from OP_functions import *

# %%
# Define paths
local = 0 #Set to 0 when working on server
paths = path(local)

# %% [markdown]
# ## THIS MUST BE THE SAME USED WHEN RUNNING PARCELS

# %%
start = datetime(2018, 12, 23) #Start date
# Set Time length [days] and timestep [seconds]
length = 10
duration = timedelta(days=length)
dt = 90 #toggle between - or + to pick backwards or forwards
N = 5 # number of deploying locations
n = 100 # 1000   # number of particles per location
dmin = [0,0,0,0,70] #minimum depth
dd = 20 #max depth difference from dmin
x_offset, y_offset, zvals = p_deploy(N,n,dmin,dd)

# %%
# Set output file name.  Maybe change for each run
fn = 'Waves1' + '_'.join(d.strftime('%Y%m%d')+'_1n' for d in [start, start+duration]) + '.nc'
outfile = os.path.join(paths['out'], fn)

# %%
Dat=xr.open_dataset(paths['coords'],decode_times=False)
outf_lat=Dat['nav_lat'][445,304]
outf_lon=Dat['nav_lon'][445,304]

# %%
lon = np.zeros([N,n])
lat = np.zeros([N,n])
# Execute run
clon, clat = [-123.901172,-125.155849,-123.207648,-123.399769,float(outf_lon)], [49.186308,49.975326,49.305448,48.399420,float(outf_lat)]  # choose horizontal centre of the particle cloud
for i in range(N):
    lon[i,:]=(clon[i] + x_offset[i,:])
    lat[i,:]=(clat[i] + y_offset[i,:])
z = zvals

# %%
coords = xr.open_dataset(paths['coords'], decode_times=False)
mask = xr.open_dataset(paths['mask'])
ds = xr.open_dataset(outfile)

# %%
visual(outfile,N,n,clon,clat,dmin,dd,0,-1,local)

# %%
profile(N,n,length,outfile,local)

# %%
#anim=mapanimation(outfile,N,n,clon,clat,1,0)
#anim

# %%
fps=2
anim = mapanimation(outfile,N,n,clon,clat,fps,local)
f = r"/home/jvalenti/MOAD/animations/PETstokes.gif" 
FFwriter = animation.FFMpegWriter()
anim.save(f, writer = FFwriter)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_983/3427123293.py in <module>
#       3 f = r"/home/jvalenti/MOAD/animations/PETstokes.gif"
#       4 FFwriter = animation.FFMpegWriter()
# ----> 5 anim.save(f, writer = FFwriter)
#
# ~/conda_envs/parcels/lib/python3.9/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1171                 for anim, d in zip(all_anim, data):
#    1172                     # TODO: See if turning off blit is really necessary
# -> 1173                     anim._draw_next_frame(d, blit=False)
#    1174                     if progress_callback is not None:
#    1175                         progress_callback(frame_number, total_frames)
#
# ~/conda_envs/parcels/lib/python3.9/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#    1206         # post- draw, as well as the drawing of the frame itself.
#    1207         self._pre_draw(framedata, blit)
# -> 1208         self._draw_frame(framedata)
#    1209         self._post_draw(framedata, blit)
#    1210
#
# ~/conda_envs/parcels/lib/python3.9/site-packages/matplotlib/animation.py in _draw_frame(self, framedata)
#    1774         # Call the func with framedata and args. If blitting is desired,
#    1775         # func needs to return a sequence of any artists that were modified.
# -> 1776         self._drawn_artists = self._func(framedata, *self._args)
#    1777
#    1778         if self._blit:
#
# ~/MOAD/analysis-jose/notebooks/parcels/OP_functions.py in update(frame)
#     103     def update(frame):
#     104         tstamp = ds.time[0, frame].values.astype('datetime64[s]').astype(datetime)
# --> 105         t.set_text(tstamp.strftime('%Y-%b-%d %H:%M UTC'))
#     106         global ss
#     107         for scat in ss:
#
# AttributeError: 'NoneType' object has no attribute 'strftime'

# %%
with open(f,'rb') as anim:
    display(Image(anim.read()))
